# %% [markdown]
# LOAD AND EXPLORE DATA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("c:/Users/kisha/Downloads/crop_dataset.csv")

print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69718 entries, 0 to 69717
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   69718 non-null  int64
#  1   N            69718 non-null  float64
#  2   Fe           69718 non-null  float64
#  3   Mn           69718 non-null  float64
#  4   S            69718 non-null  float64
#  5   Mg           69718 non-null  float64
#  6   C            69718 non-null  float64
#  7   P            69718 non-null  float64
#  8   K            69718 non-null  float64
#  9   temperature  69718 non-null  float64
#  10  humidity     69718 non-null  float64
#  11  ph           69718 non-null  float64
#  12  rainfall     69718 non-null  float64
#  13  label        69718 non-null  object
# dtypes: float64(12), int64(1), object(1)
# memory usage: 7.4+ MB
# None

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# N              0
# Fe             0
# Mn             0
# S              0
# Mg             0
# C              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# REMOVING UNNECESSARY COLUMNS

# %%
data = pd.read_csv("c:/Users/kisha/Downloads/crop_dataset.csv")
columns_to_drop = [data.columns[i] for i in [0, 2, 3, 4, 5, 6]]  
data = data.drop(columns=columns_to_drop, axis=1)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69718 entries, 0 to 69717
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            69718 non-null  float64
#  1   P            69718 non-null  float64
#  2   K            69718 non-null  float64
#  3   temperature  69718 non-null  float64
#  4   humidity     69718 non-null  float64
#  5   ph           69718 non-null  float64
#  6   rainfall     69718 non-null  float64
#  7   label        69718 non-null  object
# dtypes: float64(7), object(1)
# memory usage: 4.3+ MB
# None

# %%
data.describe()
# Out:
#                  N             P             K   temperature      humidity  \
# count  69718.00000  69718.000000  69718.000000  69718.000000  69718.000000
# mean      50.53654     53.337151     48.150327     25.621811     71.482363
# std       36.24012     32.719135     50.609850      4.647055     22.146670
# min        0.00000      5.000000      5.000000      8.825675     14.258040
# 25%       21.06250     26.656250     20.250000     22.796805     60.001913
# 50%       35.12500     50.156250     31.468750     25.627236     80.727621
# 75%       85.25000     67.875000     49.000000     28.497029     90.085664
# max      140.00000    145.000000    205.000000     43.675493     99.981876
#
#                  ph      rainfall
# count  69718.000000  69718.000000
# mean       6.470961    103.451243
# std        0.689248     53.601999
# min        3.504752     20.211267
# 25%        6.005493     66.008289
# 50%        6.442027     95.397009
# 75%        6.877140    126.324563
# ...

# %%
data.head()
# Out:
#           N     P        K  temperature   humidity        ph    rainfall label
# 0  90.00000  42.0  43.0000    20.879744  82.002744  6.502985  202.935536  rice
# 1  89.84375  42.5  42.9375    20.907579  81.950147  6.519708  203.676786  rice
# 2  89.68750  43.0  42.8750    20.935414  81.897550  6.536430  204.418036  rice
# 3  89.53125  43.5  42.8125    20.963249  81.844954  6.553152  205.159286  rice
# 4  89.37500  44.0  42.7500    20.991083  81.792357  6.569874  205.900536  rice

# %%
data.tail()
# Out:
#                N        P       K  temperature   humidity        ph  \
# 69713  105.62500  19.7500  30.500    23.936691  59.362840  6.777203
# 69714  105.21875  19.3125  30.375    23.853272  59.621248  6.777860
# 69715  104.81250  18.8750  30.250    23.769853  59.879657  6.778518
# 69716  104.40625  18.4375  30.125    23.686435  60.138066  6.779175
# 69717  104.00000  18.0000  30.000    23.603016  60.396475  6.779833
#
#          rainfall   label
# 69713  139.216823  coffee
# 69714  139.646878  coffee
# 69715  140.076932  coffee
# 69716  140.506987  coffee
# 69717  140.937041  coffee

# %% [markdown]
# MISSING VALUES

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# HANDLING DUPLICATE DATA

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# DATA UNDERSTANDING

# %%
data['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data['label'].nunique()
# Out:
# 22

# %%
data['label'].value_counts()
# Out:
# label
# rice           3169
# maize          3169
# chickpea       3169
# kidneybeans    3169
# pigeonpeas     3169
# mothbeans      3169
# mungbean       3169
# blackgram      3169
# lentil         3169
# pomegranate    3169
# banana         3169
# mango          3169
# grapes         3169
# watermelon     3169
# muskmelon      3169
# apple          3169
# orange         3169
# papaya         3169
# coconut        3169
# cotton         3169
# jute           3169
# coffee         3169
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69718 entries, 0 to 69717
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            69718 non-null  float64
#  1   P            69718 non-null  float64
#  2   K            69718 non-null  float64
#  3   temperature  69718 non-null  float64
#  4   humidity     69718 non-null  float64
#  5   ph           69718 non-null  float64
#  6   rainfall     69718 non-null  float64
#  7   label        69718 non-null  object
# dtypes: float64(7), object(1)
# memory usage: 4.3+ MB

# %%
data.describe()
# Out:
#                  N             P             K   temperature      humidity  \
# count  69718.00000  69718.000000  69718.000000  69718.000000  69718.000000
# mean      50.53654     53.337151     48.150327     25.621811     71.482363
# std       36.24012     32.719135     50.609850      4.647055     22.146670
# min        0.00000      5.000000      5.000000      8.825675     14.258040
# 25%       21.06250     26.656250     20.250000     22.796805     60.001913
# 50%       35.12500     50.156250     31.468750     25.627236     80.727621
# 75%       85.25000     67.875000     49.000000     28.497029     90.085664
# max      140.00000    145.000000    205.000000     43.675493     99.981876
#
#                  ph      rainfall
# count  69718.000000  69718.000000
# mean       6.470961    103.451243
# std        0.689248     53.601999
# min        3.504752     20.211267
# 25%        6.005493     66.008289
# 50%        6.442027     95.397009
# 75%        6.877140    126.324563
# ...

# %% [markdown]
# CORRELATION ANALYSIS

# %%
sns.pairplot(data)

# %% [markdown]
# RELATIONAL PLOT

# %%
sns.relplot(data=data,x='temperature', y='rainfall', hue = 'ph')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('dark_background')
sns.set_palette("Set1")
for i in data.columns[:-1]:
    fig,ax=plt.subplots(1,3,figsize=(18,4))
    sns.histplot(data=data,x=i,kde=True,bins=20,ax=ax[0])
    sns.violinplot(data=data,x=i,ax=ax[1])
    sns.boxplot(data=data,x=i,ax=ax[2])
    plt.suptitle(f'Visualizing {i}',size=20)

# %%
import matplotlib.pyplot as plt


numerical_cols = data.select_dtypes(include=['number']).columns
plt.figure(figsize=(12,12))
i = 1
for col in data.iloc[:, :-1]:
    plt.subplot(3, 3, i)
    box = data[[col]].boxplot(patch_artist=True)
    
    # Get the artists
    boxes = box.artists
    medians = box.lines[4::6]
    whiskers = box.lines[0::6] + box.lines[1::6]
    caps = box.lines[2::6] + box.lines[3::6]
    fliers = box.lines[5::6]

    # Set colors
    for median in medians:
        median.set(color='red', linewidth=2)
    for flier in fliers:
        flier.set(marker='o', color='yellow', alpha=0.5)
    for whisker in whiskers:
        whisker.set(color='blue', linewidth=1.5)
    for cap in caps:
        cap.set(color='green', linewidth=2)
    for box_patch in boxes:
        box_patch.set(color='purple', linewidth=2, facecolor='lightblue')
    
    plt.title(col)
    i += 1

plt.tight_layout()
plt.show()

# %%
sns.set(rc={"figure.figsize":(12,8)})
sns.boxplot(data)
# Out:
# <Axes: >

# %%
q1 = data['rainfall'].quantile(0.25)
q3 = data['rainfall'].quantile(0.75)
IQR=q3-q1
upper_limit=q3+1.5*IQR
lower_limit=q1-1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 216.79897346375003
# -24.466121906250024

# %%
data = data[data['rainfall']<upper_limit]
sns.boxplot(data['rainfall'])
# Out:
# <Axes: ylabel='rainfall'>

# %%
sns.set(rc={"figure.figsize":(12,8)})
sns.boxplot(data)
# Out:
# <Axes: >

# %% [markdown]
# SKEWNESS

# %%
data.iloc[:,:-1].skew()
# Out:
# N              0.600449
# P              1.002816
# K              2.317603
# temperature    0.106411
# humidity      -1.037761
# ph             0.347901
# rainfall       0.587183
# dtype: float64

# %%
save_path = "C:/Users/kisha/Downloads/KISHAN_TP061789_APD3F2311CSDA_FYP/KISHAN_TP061789_APD3F2311CSDA_FYP"

data.to_csv(save_path + "prepped.csv", index=False)

print("Dataset saved succesfully!")
# Out:
# Dataset saved succesfully!

# %% [markdown]
# LABEL ENCODER

# %%
names = data['label'].unique()
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['ID']=encoder.fit_transform(data['label'])
data.head()
# Out:
# C:\Users\kisha\AppData\Local\Temp\ipykernel_23592\2326148463.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ID']=encoder.fit_transform(data['label'])
#           N     P        K  temperature   humidity        ph    rainfall  \
# 0  90.00000  42.0  43.0000    20.879744  82.002744  6.502985  202.935536
# 1  89.84375  42.5  42.9375    20.907579  81.950147  6.519708  203.676786
# 2  89.68750  43.0  42.8750    20.935414  81.897550  6.536430  204.418036
# 3  89.53125  43.5  42.8125    20.963249  81.844954  6.553152  205.159286
# 4  89.37500  44.0  42.7500    20.991083  81.792357  6.569874  205.900536
#
#   label  ID
# 0  rice  20
# 1  rice  20
# 2  rice  20
# 3  rice  20
# 4  rice  20

# %%
class_labels = data['label'].unique().tolist()
class_labels = encoder.classes_
class_labels
# Out:
# array(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee',
#        'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize',
#        'mango', 'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya',
#        'pigeonpeas', 'pomegranate', 'rice', 'watermelon'], dtype=object)

# %%
label_dict = {}
for index,label in enumerate(class_labels):
    label_dict[label] = index
    
print(label_dict)
# Out:
# {'apple': 0, 'banana': 1, 'blackgram': 2, 'chickpea': 3, 'coconut': 4, 'coffee': 5, 'cotton': 6, 'grapes': 7, 'jute': 8, 'kidneybeans': 9, 'lentil': 10, 'maize': 11, 'mango': 12, 'mothbeans': 13, 'mungbean': 14, 'muskmelon': 15, 'orange': 16, 'papaya': 17, 'pigeonpeas': 18, 'pomegranate': 19, 'rice': 20, 'watermelon': 21}

# %%
from sklearn.model_selection import train_test_split


X=data.drop(['label','ID'],axis=1)
y=data['ID']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,shuffle = True, random_state = 42,stratify=y)

# %%
features = data[['N', 'P','K','temperature', 'humidity', 'ph', 'rainfall']]
target = data['ID']
labels = data['ID']

# %%
#Initializing empty lists to append all model's name and corresponding name
acc = []
model = []

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import classification_report


DecisionTree = DecisionTreeClassifier(criterion="entropy",random_state=2,max_depth=5)

DecisionTree.fit(X_train,y_train)

predicted_values = DecisionTree.predict(X_test)
x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Decision Tree')
print("DecisionTrees's Accuracy is: ", x*100)

print(classification_report(y_test,predicted_values))
# Out:
# DecisionTrees's Accuracy is:  97.24944043770206
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       950
#            1       1.00      1.00      1.00       950
#            2       0.79      1.00      0.88       951
#            3       1.00      1.00      1.00       951
#            4       1.00      1.00      1.00       905
#            5       1.00      0.99      0.99       951
#            6       1.00      1.00      1.00       950
#            7       1.00      1.00      1.00       951
#            8       0.90      0.99      0.94       951
#            9       1.00      0.91      0.95       950
#           10       0.95      1.00      0.97       951
#           11       0.90      0.99      0.95       951
#           12       1.00      1.00      1.00       950
#           13       1.00      0.68      0.81       951
#           14       1.00      1.00      1.00       951
# ...

# %%
from sklearn.naive_bayes import GaussianNB

NaiveBayes = GaussianNB()

NaiveBayes.fit(X_train,y_train)

predicted_values = NaiveBayes.predict(X_test)
x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Naive Bayes')
print("Naive Bayes's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
# Out:
# Naive Bayes's Accuracy is:  0.9976622730664014
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       950
#            1       1.00      1.00      1.00       950
#            2       1.00      1.00      1.00       951
#            3       1.00      1.00      1.00       951
#            4       1.00      1.00      1.00       905
#            5       1.00      1.00      1.00       951
#            6       1.00      1.00      1.00       950
#            7       1.00      1.00      1.00       951
#            8       0.97      0.99      0.98       951
#            9       1.00      1.00      1.00       950
#           10       0.99      1.00      1.00       951
#           11       1.00      1.00      1.00       951
#           12       1.00      1.00      1.00       950
#           13       1.00      0.99      1.00       951
#           14       1.00      1.00      1.00       951
# ...

# %%
from sklearn.svm import SVC

SVM = SVC(gamma='auto')

SVM.fit(X_train,y_train)

predicted_values = SVM.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('SVM')
print("SVM's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
# Out:
# SVM's Accuracy is:  0.9959214125839343
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       950
#            1       1.00      1.00      1.00       950
#            2       1.00      1.00      1.00       951
#            3       1.00      1.00      1.00       951
#            4       1.00      0.99      1.00       905
#            5       1.00      0.99      1.00       951
#            6       1.00      1.00      1.00       950
#            7       1.00      1.00      1.00       951
#            8       1.00      1.00      1.00       951
#            9       1.00      0.99      1.00       950
#           10       1.00      1.00      1.00       951
#           11       1.00      1.00      1.00       951
#           12       1.00      1.00      1.00       950
#           13       1.00      0.99      0.99       951
#           14       1.00      1.00      1.00       951
#           15       1.00      1.00      1.00       951
# ...

# %%
from sklearn.linear_model import LogisticRegression

LogReg = LogisticRegression(random_state=2)

LogReg.fit(X_train,y_train)

predicted_values = LogReg.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('Logistic Regression')
print("Logistic Regression's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
# Out:
# Logistic Regression's Accuracy is:  0.9838348669485203
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       950
#            1       1.00      1.00      1.00       950
#            2       0.94      0.95      0.95       951
#            3       1.00      1.00      1.00       951
#            4       1.00      1.00      1.00       905
#            5       1.00      1.00      1.00       951
#            6       0.97      0.98      0.97       950
#            7       1.00      1.00      1.00       951
#            8       0.91      0.94      0.93       951
#            9       1.00      1.00      1.00       950
#           10       0.99      0.99      0.99       951
#           11       0.97      0.97      0.97       951
#           12       1.00      1.00      1.00       950
#           13       0.95      0.94      0.95       951
#           14       0.99      1.00      0.99       951
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(X_train,y_train)

predicted_values = RF.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('RF')
print("RF's Accuracy is: ", x)

print(classification_report(y_test,predicted_values))
# Out:
# RF's Accuracy is:  0.999602089032579
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       950
#            1       1.00      1.00      1.00       950
#            2       1.00      1.00      1.00       951
#            3       1.00      1.00      1.00       951
#            4       1.00      1.00      1.00       905
#            5       1.00      1.00      1.00       951
#            6       1.00      1.00      1.00       950
#            7       1.00      1.00      1.00       951
#            8       0.99      1.00      1.00       951
#            9       1.00      1.00      1.00       950
#           10       1.00      1.00      1.00       951
#           11       1.00      1.00      1.00       951
#           12       1.00      1.00      1.00       950
#           13       1.00      1.00      1.00       951
#           14       1.00      1.00      1.00       951
#           15       1.00      1.00      1.00       951
# ...

# %%
from xgboost import XGBClassifier
from sklearn import metrics

XB = XGBClassifier()
XB.fit(X_train, y_train)

predicted_values = XB.predict(X_test)

x = metrics.accuracy_score(y_test, predicted_values)
acc.append(x)
model.append('XGBoost')

print("XGBoost's Accuracy is:", x)
print(metrics.classification_report(y_test, predicted_values))
# Out:
# XGBoost's Accuracy is: 0.9996518279035066
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       950
#            1       1.00      1.00      1.00       950
#            2       1.00      1.00      1.00       951
#            3       1.00      1.00      1.00       951
#            4       1.00      1.00      1.00       905
#            5       1.00      1.00      1.00       951
#            6       1.00      1.00      1.00       950
#            7       1.00      1.00      1.00       951
#            8       1.00      1.00      1.00       951
#            9       1.00      1.00      1.00       950
#           10       1.00      1.00      1.00       951
#           11       1.00      1.00      1.00       951
#           12       1.00      1.00      1.00       950
#           13       1.00      1.00      1.00       951
#           14       1.00      1.00      1.00       951
#           15       1.00      1.00      1.00       951
# ...

# %%
plt.figure(figsize=[10,5],dpi = 100)
plt.title('Accuracy Comparison')
plt.xlabel('Accuracy')
plt.ylabel('Algorithm')
sns.barplot(x = acc,y = model,palette='dark')
# Out:
# C:\Users\kisha\AppData\Local\Temp\ipykernel_23592\418573851.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = acc,y = model,palette='dark')
# <Axes: title={'center': 'Accuracy Comparison'}, xlabel='Accuracy', ylabel='Algorithm'>

# %%
arr=np.array([90,40,40,20,80,7,200])
arr=arr.reshape(1,-1)
x=XB.predict(arr)
y=encoder.inverse_transform(x)
data={'id':1,'Crops':y}
s=pd.DataFrame(data)
s=s.set_index("id")
s
# Out:
#    Crops
# id
# 1   jute

# %%
accuracy_models = dict(zip(model, acc))
for k, v in accuracy_models.items():
    print (k, '-->', v)
# Out:
# Decision Tree --> 0.9724944043770206
# Naive Bayes --> 0.9976622730664014
# SVM --> 0.9959214125839343
# Logistic Regression --> 0.9838348669485203
# RF --> 0.999602089032579
# XGBoost --> 0.9996518279035066

# %%
data = np.array([[104,18, 30, 23.603016, 60.3, 6.7, 140.91]])
prediction = RF.predict(data)
print(prediction)
# Out:
# [5]
# c:\Users\kisha\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

X_train = ms.fit_transform(X_train)
X_test = ms.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()


sc.fit(X_train)
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
def recommendation(N,P,k,temperature,humidity,ph,rainfal):
    features = np.array([[N,P,k,temperature,humidity,ph,rainfal]])
    transformed_features = ms.fit_transform(features)
    transformed_features = sc.fit_transform(transformed_features)
    prediction = RF.predict(transformed_features).reshape(1,-1)
    
    return prediction[0]

# %%
N = 40
P = 50
k = 50
temperature = 40.0
humidity = 20
ph = 100
rainfall = 100

predict = recommendation(N,P,k,temperature,humidity,ph,rainfall)


crop_dict = {1: "Rice", 2: "Maize", 3: "Jute", 4: "Cotton", 5: "Coconut", 6: "Papaya", 7: "Orange",
                 8: "Apple", 9: "Muskmelon", 10: "Watermelon", 11: "Grapes", 12: "Mango", 13: "Banana",
                 14: "Pomegranate", 15: "Lentil", 16: "Blackgram", 17: "Mungbean", 18: "Mothbeans",
                 19: "Pigeonpeas", 20: "Kidneybeans", 21: "Chickpea", 22: "Coffee"}

if predict[0] in crop_dict:
    crop = crop_dict[predict[0]]
    print("{} is a best crop to be cultivated ".format(crop))
else:
    print("Sorry are not able to recommend a proper crop for this environment")
# Out:
# Lentil is a best crop to be cultivated
# c:\Users\kisha\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle
pickle.dump(RF,open('model.pkl','wb'))
pickle.dump(ms,open('minmaxscaler.pkl','wb'))
pickle.dump(sc,open('standscaler.pkl','wb'))

# %%
import pickle
filename='RF_Crop.sav'
pickle.dump(RF, open(filename, 'wb'))
